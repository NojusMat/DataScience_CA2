# %% [markdown]
# # Setup

# %%
from statsbombpy import sb
import requests
import csv
import pandas as pd


competitions = sb.competitions()

matches= sb.matches(competition_id=11, season_id=27)

lineups=sb.lineups(match_id=3825848)["Levante UD"]

events = sb.events(match_id=3825848)

print(events)
events.to_csv('outputDataMining.csv', index=False)  # save as csv file
# Out:
# C:\Users\wwwno\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
# C:\Users\wwwno\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\statsbombpy\api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#      bad_behaviour_card ball_receipt_outcome ball_recovery_recovery_failure  \
# 0                   NaN                  NaN                            NaN
# 1                   NaN                  NaN                            NaN
# 2                   NaN                  NaN                            NaN
# 3                   NaN                  NaN                            NaN
# 4                   NaN                  NaN                            NaN
# ...
